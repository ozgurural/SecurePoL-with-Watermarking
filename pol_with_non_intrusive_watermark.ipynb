# %% [markdown]
# <a href="https://colab.research.google.com/github/ozgurural/SecurePoL-with-Watermarking/blob/main/pol_with_non_intrusive_watermark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ozgurural/SecurePoL-with-Watermarking.git
# Out:
# Cloning into 'SecurePoL-with-Watermarking'...
# remote: Enumerating objects: 412, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (97/97), done.
# remote: Total 412 (delta 87), reused 64 (delta 33), pack-reused 282 (from 1)
# Receiving objects: 100% (412/412), 9.17 MiB | 14.92 MiB/s, done.
# Resolving deltas: 100% (262/262), done.

# %%
# %cd SecurePoL-with-Watermarking
# Out:
# /content/SecurePoL-with-Watermarking/SecurePoL-with-Watermarking/SecurePoL-with-Watermarking

# %%
# !python PoL/train.py \
    --save-freq 100 \
    --dataset CIFAR10 \
    --model resnet20 \
    --epochs 20 \
    --lambda-wm 0.3 \
    --k 200 \
    --watermark-key 'secret_key' \
    --watermark-method 'non_intrusive' \
    --watermark-size 128 \
    --tolerance-wm 0.001 \
    --subset-size 10000
# Out:
# 2025-01-06 22:08:14,423 - INFO - Attempting to allocate 1 GPUs if available.
# 2025-01-06 22:08:14,425 - INFO - Using device: cuda
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100% 170M/170M [00:04<00:00, 41.0MB/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# 2025-01-06 22:08:24,712 - INFO - Dataset 'CIFAR10' loaded with 50000 samples.
# 2025-01-06 22:08:24,712 - INFO - Using subset_size=10000 for training.
# 2025-01-06 22:08:24,939 - INFO - Data shape: (10000, 32, 32, 3), Data type: uint8
# 2025-01-06 22:08:24,939 - INFO - First data sample hash: a3f4c00fa8a122dbe09d61bc1b6f0649e0f0dd30f22239c25f1dc0cb2d9cdbb6
# 2025-01-06 22:08:25,191 - INFO - Computed hash during training: fde2514cad1b8b159b7f8f62222036259732f9dd6415b8f568aa07d9e3dbf2bb
# 2025-01-06 22:08:25,191 - INFO - Saved dataset hash to hash.txt
# 2025-01-06 22:08:25,191 - INFO - Saved training sequence to indices.npy
# 2025-01-06 22:08:25,192 - INFO - Saved watermark info to watermark_info.json
# 2025-01-06 22:08:25,192 - INFO - Model architecture: resnet20
# 2025-01-06 22:08:25,192 - INFO - Learning Rate: 0.1
# 2025-01-06 22:08:25,192 - INFO - Batch Size: 128
# 2025-01-06 22:08:25,192 - INFO - Epochs: 20
# 2025-01-06 22:08:25,192 - INFO - Optimizer: SGD
# 2025-01-06 22:08:25,192 - INFO - Scheduler: MultiStepLR, milestones=[10, 15], gamma=0.1
# 2025-01-06 22:08:25,208 - INFO - Saved initial model checkpoint at step 0
# 2025-01-06 22:08:25,208 - INFO - Starting epoch 1/20
# 2025-01-06 22:08:26,387 - INFO - Non-intrusive WM loss computed at step=0
# 2025-01-06 22:08:29,760 - INFO - Scheduler stepped at epoch=1/20
# 2025-01-06 22:08:29,760 - INFO - Starting epoch 2/20
# 2025-01-06 22:08:30,676 - INFO - Saved checkpoint at step=100
# 2025-01-06 22:08:32,789 - INFO - Scheduler stepped at epoch=2/20
# 2025-01-06 22:08:32,789 - INFO - Starting epoch 3/20
# 2025-01-06 22:08:35,100 - INFO - Saved checkpoint at step=200
# 2025-01-06 22:08:35,136 - INFO - Non-intrusive WM loss computed at step=200
# 2025-01-06 22:08:37,042 - INFO - Scheduler stepped at epoch=3/20
# 2025-01-06 22:08:37,043 - INFO - Starting epoch 4/20
# 2025-01-06 22:08:39,642 - INFO - Saved checkpoint at step=300
# 2025-01-06 22:08:40,224 - INFO - Scheduler stepped at epoch=4/20
# 2025-01-06 22:08:40,224 - INFO - Starting epoch 5/20
# 2025-01-06 22:08:43,301 - INFO - Scheduler stepped at epoch=5/20
# 2025-01-06 22:08:43,301 - INFO - Starting epoch 6/20
# 2025-01-06 22:08:43,639 - INFO - Saved checkpoint at step=400
# 2025-01-06 22:08:43,679 - INFO - Non-intrusive WM loss computed at step=400
# 2025-01-06 22:08:46,374 - INFO - Scheduler stepped at epoch=6/20
# 2025-01-06 22:08:46,374 - INFO - Starting epoch 7/20
# 2025-01-06 22:08:47,722 - INFO - Saved checkpoint at step=500
# 2025-01-06 22:08:50,651 - INFO - Scheduler stepped at epoch=7/20
# 2025-01-06 22:08:50,651 - INFO - Starting epoch 8/20
# 2025-01-06 22:08:52,528 - INFO - Saved checkpoint at step=600
# 2025-01-06 22:08:52,544 - INFO - Non-intrusive WM loss computed at step=600
# 2025-01-06 22:08:53,708 - INFO - Scheduler stepped at epoch=8/20
# 2025-01-06 22:08:53,708 - INFO - Starting epoch 9/20
# 2025-01-06 22:08:56,384 - INFO - Saved checkpoint at step=700
# 2025-01-06 22:08:56,763 - INFO - Scheduler stepped at epoch=9/20
# 2025-01-06 22:08:56,763 - INFO - Starting epoch 10/20
# 2025-01-06 22:08:59,817 - INFO - Scheduler stepped at epoch=10/20
# 2025-01-06 22:08:59,817 - INFO - Starting epoch 11/20
# 2025-01-06 22:09:00,361 - INFO - Saved checkpoint at step=800
# 2025-01-06 22:09:00,381 - INFO - Non-intrusive WM loss computed at step=800
# 2025-01-06 22:09:04,029 - INFO - Scheduler stepped at epoch=11/20
# 2025-01-06 22:09:04,029 - INFO - Starting epoch 12/20
# 2025-01-06 22:09:05,412 - INFO - Saved checkpoint at step=900
# 2025-01-06 22:09:07,256 - INFO - Scheduler stepped at epoch=12/20
# 2025-01-06 22:09:07,256 - INFO - Starting epoch 13/20
# 2025-01-06 22:09:09,367 - INFO - Saved checkpoint at step=1000
# 2025-01-06 22:09:09,384 - INFO - Non-intrusive WM loss computed at step=1000
# 2025-01-06 22:09:10,467 - INFO - Scheduler stepped at epoch=13/20
# 2025-01-06 22:09:10,467 - INFO - Starting epoch 14/20
# 2025-01-06 22:09:13,388 - INFO - Saved checkpoint at step=1100
# 2025-01-06 22:09:13,578 - INFO - Scheduler stepped at epoch=14/20
# 2025-01-06 22:09:13,578 - INFO - Starting epoch 15/20
# 2025-01-06 22:09:17,755 - INFO - Scheduler stepped at epoch=15/20
# 2025-01-06 22:09:17,755 - INFO - Starting epoch 16/20
# 2025-01-06 22:09:18,554 - INFO - Saved checkpoint at step=1200
# 2025-01-06 22:09:18,578 - INFO - Non-intrusive WM loss computed at step=1200
# 2025-01-06 22:09:20,913 - INFO - Scheduler stepped at epoch=16/20
# 2025-01-06 22:09:20,914 - INFO - Starting epoch 17/20
# 2025-01-06 22:09:22,429 - INFO - Saved checkpoint at step=1300
# 2025-01-06 22:09:24,005 - INFO - Scheduler stepped at epoch=17/20
# 2025-01-06 22:09:24,005 - INFO - Starting epoch 18/20
# 2025-01-06 22:09:26,323 - INFO - Saved checkpoint at step=1400
# 2025-01-06 22:09:26,350 - INFO - Non-intrusive WM loss computed at step=1400
# 2025-01-06 22:09:27,143 - INFO - Scheduler stepped at epoch=18/20
# 2025-01-06 22:09:27,143 - INFO - Starting epoch 19/20
# 2025-01-06 22:09:31,109 - INFO - Saved checkpoint at step=1500
# 2025-01-06 22:09:31,166 - INFO - Scheduler stepped at epoch=19/20
# 2025-01-06 22:09:31,166 - INFO - Starting epoch 20/20
# 2025-01-06 22:09:34,284 - INFO - Scheduler stepped at epoch=20/20
# 2025-01-06 22:09:34,300 - INFO - Saved final model checkpoint at step=1580
# 2025-01-06 22:09:34,381 - ERROR - Non-intrusive watermark NOT detected; MSE=9.894671 > 0.001
# 2025-01-06 22:09:34,382 - ERROR - Non-intrusive watermark not verified; MSE exceeded 0.001 after 20 epochs.
# 2025-01-06 22:09:34,391 - INFO - Saved model_with_non_intrusive_watermark.pth
# Files already downloaded and verified
# 2025-01-06 22:09:37,433 - INFO - Validation Accuracy: 64.31%
# 2025-01-06 22:09:37,434 - INFO - Total training time: 83.01 seconds

# %%
# !python PoL/verify.py \
    --model-dir proof/CIFAR10_Batch100 \
    --dataset CIFAR10 \
    --model resnet20 \
    --epochs 2 \
    --save-freq 100 \
    --batch-size 128 \
    --lr 0.1 \
    --lambda-wm 1.0 \
    --k 50 \
    --watermark-key 'secret_key' \
    --watermark-method 'non_intrusive' \
    --watermark-size 64 \
    --dist 1 2 inf cos \
    --delta 10000 100 1 0.1 \
    --watermark-path model_with_non_intrusive_watermark.pth
# Out:
# 2024-12-22 13:37:30,106 - INFO - Starting verification process...
# 2024-12-22 13:37:30,106 - INFO - Verifying model initialization...
# /content/SecurePoL-with-Watermarking/PoL/verify.py:205: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(os.path.join(model_directory, "model_step_0"), map_location=device)
# 2024-12-22 13:37:30,410 - INFO - Initialization verification passed.
# Files already downloaded and verified
# 2024-12-22 13:37:34,781 - INFO - Saved hash from training: 40d8b2dd36df8ea21925e209d7305d262a7fdd7e670988f539080b2511019373
# 2024-12-22 13:37:34,781 - INFO - Computed hash during verification: 40d8b2dd36df8ea21925e209d7305d262a7fdd7e670988f539080b2511019373
# 2024-12-22 13:37:34,781 - INFO - Hash matches, proof-of-learning is valid.
# 2024-12-22 13:37:34,782 - INFO - Performing full verification without top-q...
# 2024-12-22 13:37:34,783 - INFO - Performing full verification on all intervals...
# 2024-12-22 13:37:34,784 - INFO - Using device: cuda
# Files already downloaded and verified
# 2024-12-22 13:37:35,678 - INFO - Dataset loaded with 50000 samples.
# /content/SecurePoL-with-Watermarking/PoL/train_with_watermark.py:88: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(model_dir, map_location=device)
# 2024-12-22 13:37:35,709 - INFO - Loaded model from proof/CIFAR10_Batch100/model_step_0
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 2024-12-22 13:37:35,710 - INFO - Model architecture: resnet20
# 2024-12-22 13:37:35,710 - INFO - Learning Rate: 0.1
# 2024-12-22 13:37:35,710 - INFO - Batch Size: 128
# 2024-12-22 13:37:35,710 - INFO - Epochs: 1
# 2024-12-22 13:37:35,710 - INFO - Optimizer: SGD
# 2024-12-22 13:37:35,710 - INFO - Scheduler: MultiStepLR with milestones [0, 0] and gamma 0.1
# 2024-12-22 13:37:35,710 - INFO - Starting epoch 1/1
# 2024-12-22 13:37:36,386 - INFO - Feature-based watermark loss computed at step 0
# 2024-12-22 13:37:40,305 - INFO - Scheduler stepped at epoch 1/1
# /content/SecurePoL-with-Watermarking/PoL/utils.py:42: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(model)
# 2024-12-22 13:37:40,444 - INFO - Using device: cuda
# Files already downloaded and verified
# 2024-12-22 13:37:41,320 - INFO - Dataset loaded with 50000 samples.
# 2024-12-22 13:37:41,356 - INFO - Loaded model from proof/CIFAR10_Batch100/model_step_100
# 2024-12-22 13:37:41,357 - INFO - Model architecture: resnet20
# 2024-12-22 13:37:41,357 - INFO - Learning Rate: 0.1
# 2024-12-22 13:37:41,357 - INFO - Batch Size: 128
# 2024-12-22 13:37:41,357 - INFO - Epochs: 1
# 2024-12-22 13:37:41,357 - INFO - Optimizer: SGD
# 2024-12-22 13:37:41,357 - INFO - Scheduler: MultiStepLR with milestones [0, 0] and gamma 0.1
# 2024-12-22 13:37:41,357 - INFO - Starting epoch 1/1
# 2024-12-22 13:37:41,613 - INFO - Feature-based watermark loss computed at step 0
# 2024-12-22 13:37:46,544 - INFO - Scheduler stepped at epoch 1/1
# 2024-12-22 13:37:46,640 - INFO - Using device: cuda
# Files already downloaded and verified
# 2024-12-22 13:37:47,526 - INFO - Dataset loaded with 50000 samples.
# 2024-12-22 13:37:47,568 - INFO - Loaded model from proof/CIFAR10_Batch100/model_step_200
# 2024-12-22 13:37:47,569 - INFO - Model architecture: resnet20
# 2024-12-22 13:37:47,569 - INFO - Learning Rate: 0.1
# 2024-12-22 13:37:47,569 - INFO - Batch Size: 128
# 2024-12-22 13:37:47,569 - INFO - Epochs: 1
# 2024-12-22 13:37:47,569 - INFO - Optimizer: SGD
# 2024-12-22 13:37:47,569 - INFO - Scheduler: MultiStepLR with milestones [0, 0] and gamma 0.1
# 2024-12-22 13:37:47,569 - INFO - Starting epoch 1/1
# 2024-12-22 13:37:47,773 - INFO - Feature-based watermark loss computed at step 0
# 2024-12-22 13:37:51,679 - INFO - Scheduler stepped at epoch 1/1
# 2024-12-22 13:37:51,720 - INFO - Using device: cuda
# Files already downloaded and verified
# 2024-12-22 13:37:52,603 - INFO - Dataset loaded with 50000 samples.
# 2024-12-22 13:37:52,641 - INFO - Loaded model from proof/CIFAR10_Batch100/model_step_300
# 2024-12-22 13:37:52,641 - INFO - Model architecture: resnet20
# 2024-12-22 13:37:52,641 - INFO - Learning Rate: 0.1
# 2024-12-22 13:37:52,641 - INFO - Batch Size: 128
# 2024-12-22 13:37:52,641 - INFO - Epochs: 1
# 2024-12-22 13:37:52,641 - INFO - Optimizer: SGD
# 2024-12-22 13:37:52,641 - INFO - Scheduler: MultiStepLR with milestones [0, 0] and gamma 0.1
# 2024-12-22 13:37:52,641 - INFO - Starting epoch 1/1
# 2024-12-22 13:37:52,890 - INFO - Feature-based watermark loss computed at step 0
# 2024-12-22 13:37:56,703 - INFO - Scheduler stepped at epoch 1/1
# 2024-12-22 13:37:56,753 - INFO - Using device: cuda
# Files already downloaded and verified
# 2024-12-22 13:37:57,719 - INFO - Dataset loaded with 50000 samples.
# 2024-12-22 13:37:57,771 - INFO - Loaded model from proof/CIFAR10_Batch100/model_step_400
# 2024-12-22 13:37:57,772 - INFO - Model architecture: resnet20
# 2024-12-22 13:37:57,772 - INFO - Learning Rate: 0.1
# 2024-12-22 13:37:57,772 - INFO - Batch Size: 128
# 2024-12-22 13:37:57,772 - INFO - Epochs: 1
# 2024-12-22 13:37:57,772 - INFO - Optimizer: SGD
# 2024-12-22 13:37:57,772 - INFO - Scheduler: MultiStepLR with milestones [0, 0] and gamma 0.1
# 2024-12-22 13:37:57,772 - INFO - Starting epoch 1/1
# 2024-12-22 13:37:58,141 - INFO - Feature-based watermark loss computed at step 0
# 2024-12-22 13:38:03,091 - INFO - Scheduler stepped at epoch 1/1
# 2024-12-22 13:38:03,128 - INFO - Using device: cuda
# Files already downloaded and verified
# 2024-12-22 13:38:04,009 - INFO - Dataset loaded with 50000 samples.
# 2024-12-22 13:38:04,046 - INFO - Loaded model from proof/CIFAR10_Batch100/model_step_500
# 2024-12-22 13:38:04,047 - INFO - Model architecture: resnet20
# 2024-12-22 13:38:04,047 - INFO - Learning Rate: 0.1
# 2024-12-22 13:38:04,047 - INFO - Batch Size: 128
# 2024-12-22 13:38:04,047 - INFO - Epochs: 1
# 2024-12-22 13:38:04,047 - INFO - Optimizer: SGD
# 2024-12-22 13:38:04,047 - INFO - Scheduler: MultiStepLR with milestones [0, 0] and gamma 0.1
# 2024-12-22 13:38:04,047 - INFO - Starting epoch 1/1
# 2024-12-22 13:38:04,277 - INFO - Feature-based watermark loss computed at step 0
# 2024-12-22 13:38:08,126 - INFO - Scheduler stepped at epoch 1/1
# 2024-12-22 13:38:08,163 - INFO - Using device: cuda
# Files already downloaded and verified
# 2024-12-22 13:38:09,047 - INFO - Dataset loaded with 50000 samples.
# 2024-12-22 13:38:09,086 - INFO - Loaded model from proof/CIFAR10_Batch100/model_step_600
# 2024-12-22 13:38:09,086 - INFO - Model architecture: resnet20
# 2024-12-22 13:38:09,086 - INFO - Learning Rate: 0.1
# 2024-12-22 13:38:09,086 - INFO - Batch Size: 128
# 2024-12-22 13:38:09,086 - INFO - Epochs: 1
# 2024-12-22 13:38:09,086 - INFO - Optimizer: SGD
# 2024-12-22 13:38:09,086 - INFO - Scheduler: MultiStepLR with milestones [0, 0] and gamma 0.1
# 2024-12-22 13:38:09,086 - INFO - Starting epoch 1/1
# 2024-12-22 13:38:09,268 - INFO - Feature-based watermark loss computed at step 0
# 2024-12-22 13:38:14,042 - INFO - Scheduler stepped at epoch 1/1
# 2024-12-22 13:38:14,099 - INFO - Using device: cuda
# Files already downloaded and verified
# 2024-12-22 13:38:15,006 - INFO - Dataset loaded with 50000 samples.
# 2024-12-22 13:38:15,044 - INFO - Loaded model from proof/CIFAR10_Batch100/model_step_700
# 2024-12-22 13:38:15,044 - INFO - Model architecture: resnet20
# 2024-12-22 13:38:15,044 - INFO - Learning Rate: 0.1
# 2024-12-22 13:38:15,044 - INFO - Batch Size: 128
# 2024-12-22 13:38:15,045 - INFO - Epochs: 1
# 2024-12-22 13:38:15,045 - INFO - Optimizer: SGD
# 2024-12-22 13:38:15,045 - INFO - Scheduler: MultiStepLR with milestones [0, 0] and gamma 0.1
# 2024-12-22 13:38:15,045 - INFO - Starting epoch 1/1
# 2024-12-22 13:38:15,273 - INFO - Feature-based watermark loss computed at step 0
# 2024-12-22 13:38:18,449 - INFO - Scheduler stepped at epoch 1/1
# 2024-12-22 13:38:18,486 - INFO - Using device: cuda
# Files already downloaded and verified
# 2024-12-22 13:38:19,362 - INFO - Dataset loaded with 50000 samples.
# 2024-12-22 13:38:19,399 - INFO - Loaded model from proof/CIFAR10_Batch100/model_step_800
# 2024-12-22 13:38:19,400 - INFO - Model architecture: resnet20
# 2024-12-22 13:38:19,400 - INFO - Learning Rate: 0.1
# 2024-12-22 13:38:19,400 - INFO - Batch Size: 128
# 2024-12-22 13:38:19,400 - INFO - Epochs: 1
# 2024-12-22 13:38:19,400 - INFO - Optimizer: SGD
# 2024-12-22 13:38:19,400 - INFO - Scheduler: MultiStepLR with milestones [0, 0] and gamma 0.1
# 2024-12-22 13:38:19,400 - INFO - Starting epoch 1/1
# 2024-12-22 13:38:19,496 - INFO - Scheduler stepped at epoch 1/1
# 2024-12-22 13:38:19,534 - INFO - Using device: cuda
# Files already downloaded and verified
# 2024-12-22 13:38:20,414 - INFO - Dataset loaded with 50000 samples.
# 2024-12-22 13:38:20,454 - INFO - Loaded model from proof/CIFAR10_Batch100/model_step_900
# 2024-12-22 13:38:20,455 - INFO - Model architecture: resnet20
# 2024-12-22 13:38:20,455 - INFO - Learning Rate: 0.1
# 2024-12-22 13:38:20,455 - INFO - Batch Size: 128
# 2024-12-22 13:38:20,455 - INFO - Epochs: 1
# 2024-12-22 13:38:20,455 - INFO - Optimizer: SGD
# 2024-12-22 13:38:20,455 - INFO - Scheduler: MultiStepLR with milestones [0, 0] and gamma 0.1
# 2024-12-22 13:38:20,455 - INFO - Starting epoch 1/1
# 2024-12-22 13:38:20,552 - INFO - Scheduler stepped at epoch 1/1
# 2024-12-22 13:38:20,592 - INFO - Using device: cuda
# Files already downloaded and verified
# 2024-12-22 13:38:21,484 - INFO - Dataset loaded with 50000 samples.
# 2024-12-22 13:38:21,523 - INFO - Loaded model from proof/CIFAR10_Batch100/model_step_1000
# 2024-12-22 13:38:21,523 - INFO - Model architecture: resnet20
# 2024-12-22 13:38:21,524 - INFO - Learning Rate: 0.1
# 2024-12-22 13:38:21,524 - INFO - Batch Size: 128
# 2024-12-22 13:38:21,524 - INFO - Epochs: 1
# 2024-12-22 13:38:21,524 - INFO - Optimizer: SGD
# 2024-12-22 13:38:21,524 - INFO - Scheduler: MultiStepLR with milestones [0, 0] and gamma 0.1
# 2024-12-22 13:38:21,524 - INFO - Starting epoch 1/1
# 2024-12-22 13:38:21,619 - INFO - Scheduler stepped at epoch 1/1
# 2024-12-22 13:38:21,656 - INFO - Using device: cuda
# Files already downloaded and verified
# 2024-12-22 13:38:22,530 - INFO - Dataset loaded with 50000 samples.
# 2024-12-22 13:38:22,571 - INFO - Loaded model from proof/CIFAR10_Batch100/model_step_1100
# 2024-12-22 13:38:22,572 - INFO - Model architecture: resnet20
# 2024-12-22 13:38:22,572 - INFO - Learning Rate: 0.1
# 2024-12-22 13:38:22,572 - INFO - Batch Size: 128
# 2024-12-22 13:38:22,572 - INFO - Epochs: 1
# 2024-12-22 13:38:22,572 - INFO - Optimizer: SGD
# 2024-12-22 13:38:22,572 - INFO - Scheduler: MultiStepLR with milestones [0, 0] and gamma 0.1
# 2024-12-22 13:38:22,572 - INFO - Starting epoch 1/1
# 2024-12-22 13:38:22,666 - INFO - Scheduler stepped at epoch 1/1
# 2024-12-22 13:38:22,702 - INFO - Using device: cuda
# Files already downloaded and verified
# 2024-12-22 13:38:23,595 - INFO - Dataset loaded with 50000 samples.
# 2024-12-22 13:38:23,634 - INFO - Loaded model from proof/CIFAR10_Batch100/model_step_1200
# 2024-12-22 13:38:23,634 - INFO - Model architecture: resnet20
# 2024-12-22 13:38:23,634 - INFO - Learning Rate: 0.1
# 2024-12-22 13:38:23,634 - INFO - Batch Size: 128
# 2024-12-22 13:38:23,634 - INFO - Epochs: 1
# 2024-12-22 13:38:23,635 - INFO - Optimizer: SGD
# 2024-12-22 13:38:23,635 - INFO - Scheduler: MultiStepLR with milestones [0, 0] and gamma 0.1
# 2024-12-22 13:38:23,635 - INFO - Starting epoch 1/1
# 2024-12-22 13:38:23,728 - INFO - Scheduler stepped at epoch 1/1
# 2024-12-22 13:38:23,766 - INFO - Using device: cuda
# Files already downloaded and verified
# 2024-12-22 13:38:24,670 - INFO - Dataset loaded with 50000 samples.
# 2024-12-22 13:38:24,730 - INFO - Loaded model from proof/CIFAR10_Batch100/model_step_1300
# 2024-12-22 13:38:24,731 - INFO - Model architecture: resnet20
# 2024-12-22 13:38:24,731 - INFO - Learning Rate: 0.1
# 2024-12-22 13:38:24,731 - INFO - Batch Size: 128
# 2024-12-22 13:38:24,731 - INFO - Epochs: 1
# 2024-12-22 13:38:24,731 - INFO - Optimizer: SGD
# 2024-12-22 13:38:24,731 - INFO - Scheduler: MultiStepLR with milestones [0, 0] and gamma 0.1
# 2024-12-22 13:38:24,731 - INFO - Starting epoch 1/1
# 2024-12-22 13:38:24,882 - INFO - Scheduler stepped at epoch 1/1
# 2024-12-22 13:38:24,939 - INFO - Using device: cuda
# Files already downloaded and verified
# 2024-12-22 13:38:25,911 - INFO - Dataset loaded with 50000 samples.
# 2024-12-22 13:38:25,976 - INFO - Loaded model from proof/CIFAR10_Batch100/model_step_1400
# 2024-12-22 13:38:25,977 - INFO - Model architecture: resnet20
# 2024-12-22 13:38:25,977 - INFO - Learning Rate: 0.1
# 2024-12-22 13:38:25,977 - INFO - Batch Size: 128
# 2024-12-22 13:38:25,977 - INFO - Epochs: 1
# 2024-12-22 13:38:25,977 - INFO - Optimizer: SGD
# 2024-12-22 13:38:25,977 - INFO - Scheduler: MultiStepLR with milestones [0, 0] and gamma 0.1
# 2024-12-22 13:38:25,977 - INFO - Starting epoch 1/1
# 2024-12-22 13:38:26,118 - INFO - Scheduler stepped at epoch 1/1
# 2024-12-22 13:38:26,180 - INFO - Using device: cuda
# Files already downloaded and verified
# 2024-12-22 13:38:27,149 - INFO - Dataset loaded with 50000 samples.
# 2024-12-22 13:38:27,219 - INFO - Loaded model from proof/CIFAR10_Batch100/model_step_1500
# 2024-12-22 13:38:27,220 - INFO - Model architecture: resnet20
# 2024-12-22 13:38:27,220 - INFO - Learning Rate: 0.1
# 2024-12-22 13:38:27,220 - INFO - Batch Size: 128
# 2024-12-22 13:38:27,220 - INFO - Epochs: 1
# 2024-12-22 13:38:27,220 - INFO - Optimizer: SGD
# 2024-12-22 13:38:27,220 - INFO - Scheduler: MultiStepLR with milestones [0, 0] and gamma 0.1
# 2024-12-22 13:38:27,220 - INFO - Starting epoch 1/1
# 2024-12-22 13:38:27,315 - INFO - Scheduler stepped at epoch 1/1
# 2024-12-22 13:38:27,352 - INFO - Full verification results:
# 2024-12-22 13:38:27,353 - INFO - Metric: 1, Threshold: 10000.0, Avg: 23.3150, Max: 84.1780, Min: 0.0000
# 2024-12-22 13:38:27,353 - INFO - No steps exceed threshold for metric 1. PoL appears valid.
# 2024-12-22 13:38:27,353 - INFO - Metric: 2, Threshold: 100.0, Avg: 0.0701, Max: 0.2681, Min: 0.0000
# 2024-12-22 13:38:27,353 - INFO - No steps exceed threshold for metric 2. PoL appears valid.
# 2024-12-22 13:38:27,353 - INFO - Metric: inf, Threshold: 1.0, Avg: 0.0039, Max: 0.0182, Min: 0.0000
# 2024-12-22 13:38:27,353 - INFO - No steps exceed threshold for metric inf. PoL appears valid.
# 2024-12-22 13:38:27,354 - INFO - Metric: cos, Threshold: 0.1, Avg: 0.0000, Max: 0.0000, Min: -0.0000
# 2024-12-22 13:38:27,354 - INFO - No steps exceed threshold for metric cos. PoL appears valid.
# 2024-12-22 13:38:27,354 - INFO - Verifying watermark presence in the model...
# /content/SecurePoL-with-Watermarking/PoL/verify.py:405: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(model_path, map_location=device)
# 2024-12-22 13:38:27,386 - INFO - Starting feature-based watermark validation.
# 2024-12-22 13:38:27,399 - INFO - Feature-based watermark validation successful: Watermark detected.
# 2024-12-22 13:38:27,399 - INFO - Feature-based watermark verification successful: Watermark is present in the model.
# 2024-12-22 13:38:27,399 - INFO - Verification process completed successfully.
